# %%
from google.cloud import bigquery
from google.oauth2 import service_account

# credentials = compute_engine.Credentials(service_account_email="streamlit-acc@leafy-tuner-396605.iam.gserviceaccount.com")
projectID = "alert-passkey-392415"
key_path="/Users/evejacob/code/Evej2000/gcp/unique-moon-392415-52adc867705b.json"

credentials = service_account.Credentials.from_service_account_file(key_path)

dataset_id = 'artsyfartscidata'
datasetID = "artsyfartscidata"
tableID = "image_data_balanced_new_index"

client = bigquery.Client(project=projectID, credentials=credentials)

# %%
# https://console.cloud.google.com/bigquery?ws=!1m5!1m4!4m3!1salert-passkey-392415!2sartsyfartscidata!3simage_data_balanced

#ob_config = bigquery.QueryJobConfig()

# %%
# Set the destination table
#table_ref = client.dataset("artsyfartscidata").table("image_data_balanced_new_index")
#job_config.destination = table_ref
sql = """
SELECT 
  artwork_id,
  title,
  category,
  medium,
  date,
  height_cm,
  width_cm,
  collecting_institution,
  image_url_template,
  image_url_normalized
FROM `alert-passkey-392415.artsyfartscidata.image_data_balanced_new_index`
LIMIT 10
"""

# %%
# Start the query, passing in the extra configuration.
query_job = client.query(
    sql).to_dataframe()
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    #location="EU",
    #job_config=job_config,
  # API request - starts the query

# %%
query_job.head()
# Out:
#                  artwork_id  \
# 0  4eb311ad48eeb80001010d3b
# 1  5035a0fa9e387b000200077d
# 2  5035a0ed9e387b000200070d
# 3  535181b1139b219fb80000c8
# 4  5035a0f2f852da0002000710
#
#                                                title  category  \
# 0  Entrez donc dans la mer sans crainte... (Enter...     Print
# 1  Medallion with the Emperor Augustus's Vision o...  Painting
# 2             Wall Painting: Woman Holding a Sistrum  Painting
# 3                          Still Life with Asparagus  Painting
# 4                             Resurrection of Christ  Painting
#
#                                               medium                date  \
# 0                            Hand-colored lithograph                1856
# 1  Painted enamel on silver (?) with gilded silve...            ca. 1420
# 2  Neutral gray, red, black, white, blue and yell...  ca. 1250-1200 B.C.
# 3                              Oil on paper on panel                1697
# 4                       Tempera on wood with gilding       ca. 1350-1375
#
#    height_cm  width_cm collecting_institution  \
# 0       19.4      24.9                   None
# 1        6.0       5.2                   None
# 2       24.0      17.0                   None
# 3       25.0      20.5                   None
# 4       36.0      26.5                   None
#
#                                   image_url_template  \
# 0  https://d32dm0rphc51dk.cloudfront.net/3TZba-SK...
# 1  https://d32dm0rphc51dk.cloudfront.net/9Jbi08aY...
# 2  https://d32dm0rphc51dk.cloudfront.net/yv_4mJ9h...
# 3  https://d32dm0rphc51dk.cloudfront.net/QiJz5owB...
# 4  https://d32dm0rphc51dk.cloudfront.net/VWQE50YN...
#
#                                 image_url_normalized
# 0  https://d32dm0rphc51dk.cloudfront.net/3TZba-SK...
# 1  https://d32dm0rphc51dk.cloudfront.net/9Jbi08aY...
# 2  https://d32dm0rphc51dk.cloudfront.net/yv_4mJ9h...
# 3  https://d32dm0rphc51dk.cloudfront.net/QiJz5owB...
# 4  https://d32dm0rphc51dk.cloudfront.net/VWQE50YN...
